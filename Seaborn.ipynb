# %% [markdown]
# <a href="https://colab.research.google.com/github/Jwainlee/python-baby/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sn

iris = sn.load_dataset('iris')
tips = sn.load_dataset('tips')

x = iris.sepal_length

plt.hist(x)
plt.title('Sepal length hist')
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sn.distplot(x, hist = True, kde = True)
plt.title('hist & dens')
plt.show()
# Out:
# <ipython-input-4-fd6485029607>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(x, hist = True, kde = True)

# %%
sn.pairplot(data = iris, hue = 'species', kind = 'scatter')
plt.show()

# %%
sn.scatterplot(x = 'sepal_length', y = 'petal_length', data = iris)
plt.show()

sn.scatterplot(x = 'sepal_length', y = 'petal_length', hue = 'species', data = iris)
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sn.relplot(x = 'total_bill', y = 'tip', size = 'size', sizes = (15,100), data = tips)
plt.show()
